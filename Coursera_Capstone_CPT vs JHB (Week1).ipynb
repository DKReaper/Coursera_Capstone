# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 1)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try and compare South Africa's two biggest cities, namely Johannesburg and Cape Town.
# This report is targeted at tourism businesses but can be used to inform a variety of business and or lifestyle decisions.
#
# We will attempt to **classify all neighborhoods for both cities collectively** by analysing their **venue composition**.
# Once the neighborhoods have been classified we can **review the distribution of these classes across the two cities**.
#
# Reviewing the distribution of neighborhood classes will hopefully reveal an additional layer of insight that can be used to inform the structuring of tourism packages. This will also give a general idea of how the lifestyle for the areas would be similar or differ from city to city.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# A description of the data and how it will be used to solve the problem.
#
# Following data sources will be needed to extract/generate the required information:
# - List of neighborhoods for each city (collected from Wikipedia)
# - List of coordinates for each neighborhood (collected using Geopy Nominatim Module)
# - List of venues for each neighborhood including their associated category (collected using FourSquare API)
#
# Once the data is obtained we will need to perform the following analysis:
# - Classify all neighborhoods, collectively, in terms of venue composition using Kmeans clustering
# - Analyse the distribution of the neighborhood classes across the two cities to gauge similarity
# - Plot the neighborhoods on a map to view the geographical distribution of the neighborhood classes

# %%
# FourSquare API information

api_secretspath = r'C:\Temp\FourSquare_AppSecret.txt'

with open(api_secretspath, "r") as secret_content:
    lines = secret_content.readlines()
    
CLIENT_ID = lines[0].rstrip() # Foursquare ID
CLIENT_SECRET = lines[1].rstrip() #Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
# Module Imports
import requests # library to handle requests
import numpy as np # useful for many scientific computing in Python
import pandas as pd # primary data structure library

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

from sklearn.cluster import KMeans # import k-means from clustering stage

# Matplotlib and associated plotting modules
import folium # Geographic plotting library
from matplotlib import pyplot as plt # Plotting library
import matplotlib.cm as cm # Module used for generating colors
import matplotlib.colors as colors # Module used for generating colors

# %% [markdown]
# ### Getting a list of neighborhoods per city
#
# The below links contain the information required.
# - https://en.wikipedia.org/wiki/List_of_Cape_Town_suburbs
# - https://en.wikipedia.org/wiki/Suburbs_of_Johannesburg
#
# The data is unfortunately not very well structured. It was decided to manually extract the list of neighborhoods and save them into text files which could then be imported. Along with saving the neighborhood names, the city was appended after a comma to facilitate the coordinate lookups.

# %%
# Reading in list of neighborhoods from text files

# Creating empty list
cpt_suburbs = []

# File Paths
cpt_listpath = r"Data\CapeTown_neighbourhood.txt"

# Open the files and read in the data
with open(cpt_listpath, "r") as cpt_content:
    lines = cpt_content.readlines()
    for l in lines:
        cpt_suburbs.append(l)

# Display sample of the lists
print('Cape Town - First 5 Neigborhoods of {}'.format(len(cpt_suburbs)))
cpt_suburbs[0:4]
# Out:
# Cape Town - First 5 Neigborhoods of 135
# ['Athlone, Cape Town\n',
#  'Atlantis, Cape Town\n',
#  'Bakoven, Cape Town\n',
#  'Bantry Bay, Cape Town\n']

# %%
# Reading in list of neighborhoods from text files

# Creating empty list
jhb_suburbs = []

# File Paths
jhb_listpath = r"Data\Johannesburg_neighbourhood.txt"

with open(jhb_listpath, "r") as jhb_content:
    lines = jhb_content.readlines()
    for l in lines:
        jhb_suburbs.append(l)

print('Johannesburg - First 5 Neigborhoods of {}'.format(len(jhb_suburbs)))
jhb_suburbs[0:5]
# Out:
# Johannesburg - First 5 Neigborhoods of 358
# ['Abbotsford, Johannesburg\n',
#  'Aeroton, Johannesburg\n',
#  'Airdlin, Johannesburg\n',
#  'Alan Manor, Johannesburg\n',
#  'Albertskroon, Johannesburg\n']

# %% [markdown]
# ### Adding longitude and latitude coordinates for all the neighborhoods
#
# Now that we have a list of all the neighborhoods, we need to find their coordinates.
# We will make use of the Nominatim module to do this.
#
# As the data source is likely to not be accurate, we will also be gathering actual addresses along with coordinates.
# This data will be used to ensure we have good information before performing any analysis.

# %%
# function for getting location information and coordinates
def get_locdata(searchstring):
    
    result = {}
       
    print("Searching : {}".format(searchstring)) # print information to keep track of progress
    
    try:
        geolocator = Nominatim(user_agent="sa_explorer")
        location = geolocator.geocode(searchstring)
        
        result['searchstring'] = searchstring
        result['address'] = location.address
        result['longitude'] = location.longitude
        result['latitude'] = location.latitude
    
    except: # unable to gather information, store None Values
        
        result['searchstring'] = searchstring
        result['address'] = None
        result['longitude'] = None
        result['latitude'] = None
        
    return result

# %%
# Gathering Location information

# Merge list of neighborhoods to be searched  
all_suburbs = cpt_suburbs + jhb_suburbs

# Create empty list to capture results of the searches
locdata = []

for loc in all_suburbs:
    locdata.append(get_locdata(loc.rstrip()))
# Out:
# Searching : Athlone, Cape Town
# Searching : Atlantis, Cape Town
# Searching : Bakoven, Cape Town
# Searching : Bantry Bay, Cape Town
# Searching : Belhar, Cape Town
# Searching : Bellville, Cape Town
# Searching : Bergvliet, Cape Town
# Searching : Bishop Lavis, Cape Town
# Searching : Bishopscourt, Cape Town
# Searching : Bloubergstrand, Cape Town
# Searching : Bo-Kaap, Cape Town
# Searching : Bonteheuwel, Cape Town
# Searching : Bothasig, Cape Town
# Searching : Brackenfell, Cape Town
# Searching : Brooklyn, Cape Town
# Searching : Camps Bay, Cape Town
# Searching : Capri Village, Cape Town
# Searching : Claremont, Cape Town
# Searching : Clifton, Cape Town
# Searching : Clovelly, Cape Town
# Searching : Constantia, Cape Town
# Searching : Crawford, Cape Town
# Searching : Crossroads, Cape Town
# Searching : Darling, Cape Town
# Searching : De Waterkant, Cape Town
# Searching : Delft, Cape Town
# Searching : Devil's Peak Estate, Cape Town
# Searching : Diep River, Cape Town
# Searching : Durbanville, Cape Town
# Searching : Edgemead, Cape Town
# Searching : Eersteriver, Cape Town
# Searching : Elsie's River, Cape Town
# Searching : Epping, Cape Town
# Searching : Firgrove, Cape Town
# Searching : Fish Hoek, Cape Town
# Searching : Foreshore, Cape Town
# Searching : Fresnaye, Cape Town
# Searching : Gardens, Cape Town
# Searching : Glencairn, Cape Town
# Searching : Goodwood, Cape Town
# Searching : Gordon's Bay, Cape Town
# Searching : Grassy Park, Cape Town
# Searching : Green Point, Cape Town
# Searching : Gugulethu, Cape Town
# Searching : Hanover Park, Cape Town
# Searching : Harfield Village, Cape Town
# Searching : Heathfield, Cape Town
# Searching : Higgovale, Cape Town
# Searching : Hout Bay, Cape Town
# Searching : Imizamo Yethu, Cape Town
# Searching : Kalk Bay, Cape Town
# Searching : Kalksteenfontein, Cape Town
# Searching : Kenilworth, Cape Town
# Searching : Kensington, Cape Town
# Searching : Kenwyn, Cape Town
# Searching : Khayelitsha, Cape Town
# Searching : Kirstenhof, Cape Town
# Searching : Kommetjie, Cape Town
# Searching : Kraaifontein, Cape Town
# Searching : Kreupelbosch, Cape Town
# Searching : Kuils River, Cape Town
# Searching : Lakeside, Cape Town
# Searching : Langa, Cape Town
# Searching : Lansdowne, Cape Town
# Searching : Lavender Hill, Cape Town
# Searching : Llandudno, Cape Town
# Searching : Loevenstein, Cape Town
# Searching : Lotus River, Cape Town
# Searching : Lower Vrede, Cape Town
# Searching : Macassar, Cape Town
# Searching : Maitland, Cape Town
# Searching : Mamre, Cape Town
# Searching : Manenberg, Cape Town
# Searching : Marina da Gama, Cape Town
# Searching : Masiphumelele, Cape Town
# Searching : Meadowridge, Cape Town
# Searching : Melkbosstrand, Cape Town
# Searching : Milnerton, Cape Town
# Searching : Mitchells Plain, Cape Town
# Searching : Montague Gardens, Cape Town
# Searching : Monte Vista, Cape Town
# Searching : Mouille Point, Cape Town
# Searching : Mowbray, Cape Town
# Searching : Muizenberg, Cape Town
# Searching : Ndabeni, Cape Town
# Searching : Newlands, Cape Town
# Searching : Noordhoek, Cape Town
# Searching : Nyanga, Cape Town
# Searching : Observatory, Cape Town
# Searching : Ocean View, Cape Town
# Searching : Oranjezicht, Cape Town
# Searching : Ottery, Cape Town
# Searching : Panorama, Cape Town
# Searching : Parklands, Cape Town
# Searching : Parow, Cape Town
# Searching : Pelican Park, Cape Town
# Searching : Philippi, Cape Town
# Searching : Pinelands, Cape Town
# Searching : Plattekloof, Cape Town
# Searching : Plumstead, Cape Town
# Searching : Retreat, Cape Town
# Searching : Rondebosch, Cape Town
# Searching : Rondebosch East, Cape Town
# Searching : Rosebank, Cape Town
# Searching : Rugby, Cape Town
# Searching : Salt River, Cape Town
# Searching : Samora Machel, Cape Town
# Searching : Scarborough, Cape Town
# Searching : Schotsche Kloof, Cape Town
# Searching : Sea Point, Cape Town
# Searching : Simon's Town, Cape Town
# Searching : Sir Lowry's Pass Village, Cape Town
# Searching : Somerset West, Cape Town
# Searching : SouthField, Cape Town
# Searching : St James, Cape Town
# Searching : Steenberg, Cape Town
# Searching : Strand, Cape Town
# Searching : Strandfontein, Cape Town
# Searching : Sun Valley, Cape Town
# Searching : Sunnydale, Cape Town
# Searching : Table View, Cape Town
# Searching : Tamboerskloof, Cape Town
# Searching : Thornton, Cape Town
# Searching : Three Anchor Bay, Cape Town
# Searching : Tokai, Cape Town
# Searching : University Estate, Cape Town
# Searching : Valhalla Park, Cape Town
# Searching : Vredehoek, Cape Town
# Searching : Vrygrond, Cape Town
# Searching : Walmer Estate, Cape Town
# Searching : West Beach, Cape Town
# Searching : Wetton, Cape Town
# Searching : Woodstock, Cape Town
# Searching : Wynberg, Cape Town
# Searching : Zonnebloem, Cape Town
# Searching : Abbotsford, Johannesburg
# Searching : Aeroton, Johannesburg
# Searching : Airdlin, Johannesburg
# Searching : Alan Manor, Johannesburg
# Searching : Albertskroon, Johannesburg
# Searching : Albertville, Johannesburg
# Searching : Aldara Park, Johannesburg
# Searching : Alexandra, Johannesburg
# Searching : Amalgam, Johannesburg
# Searching : Aspen Hills, Johannesburg
# Searching : Atholhurst, Johannesburg
# Searching : Atholl, Johannesburg
# Searching : Atholl Gardens, Johannesburg
# Searching : Auckland Park, Johannesburg
# Searching : Bagleyston, Johannesburg
# Searching : Barbeque Downs, Johannesburg
# Searching : Barbeque Downs Business Park, Johannesburg
# Searching : Bellevue, Johannesburg
# Searching : Bellevue East, Johannesburg
# Searching : Benmore Gardens, Johannesburg
# Searching : Benrose, Johannesburg
# Searching : Berario, Johannesburg
# Searching : Berea, Johannesburg
# Searching : Bertrams, Johannesburg
# Searching : Beverley Gardens, Johannesburg
# Searching : Birdhaven, Johannesburg
# Searching : Birnam, Johannesburg
# Searching : Blackheath, Johannesburg
# Searching : Blairgowrie, Johannesburg
# Searching : Bloubosrand, Johannesburg
# Searching : Blue Hills, Johannesburg
# Searching : Bordeaux, Johannesburg
# Searching : Bosmont, Johannesburg
# Searching : Braamfontein, Johannesburg
# Searching : Braamfontein Werf, Johannesburg
# Searching : Bramley, Johannesburg
# Searching : Bramley North, Johannesburg
# Searching : Bramley Park, Johannesburg
# Searching : Brixton, Johannesburg
# Searching : Broadacres, Johannesburg
# Searching : Bromhof, Johannesburg
# Searching : Bruma, Johannesburg
# Searching : Bryanbrink, Johannesburg
# Searching : Bryanston, Johannesburg
# Searching : Bryanston East, Johannesburg
# Searching : Bryanston West, Johannesburg
# Searching : Buccleuch, Johannesburg
# Searching : Bush Hill, Johannesburg
# Searching : Carlswald, Johannesburg
# Searching : Chartwell, Johannesburg
# Searching : Cheltondale, Johannesburg
# Searching : Chislehurston, Johannesburg
# Searching : Chrisville, Johannesburg
# Searching : City and Suburban, Johannesburg
# Searching : City and Suburban Industrial, Johannesburg
# Searching : City Deep, Johannesburg
# Searching : City West-Denver, Johannesburg
# Searching : Clynton, Johannesburg
# Searching : Constantia Kloof, Johannesburg
# Searching : Country Life Park, Johannesburg
# Searching : Country View, Johannesburg
# Searching : Cowdray Park, Johannesburg
# Searching : Craighall, Johannesburg
# Searching : Craighall Park, Johannesburg
# Searching : Cramerview, Johannesburg
# Searching : Cresta, Johannesburg
# Searching : Crosby, Johannesburg
# Searching : Crown, Johannesburg
# Searching : Crown Gardens, Johannesburg
# Searching : Crown North, Johannesburg
# Searching : Crowthorne, Johannesburg
# Searching : Cyrildene, Johannesburg
# Searching : Dainfern, Johannesburg
# Searching : Dalecross, Johannesburg
# Searching : Daniel Brink Park, Johannesburg
# Searching : Darrenwood, Johannesburg
# Searching : Dennehof, Johannesburg
# Searching : Diepkloof, Johannesburg
# Searching : Diepsloot, Johannesburg
# Searching : Dobsonville, Johannesburg
# Searching : Doornfontein, Johannesburg
# Searching : Doornkop, Johannesburg
# Searching : Douglasdale, Johannesburg
# Searching : Droste Park, Johannesburg
# Searching : Dunhill, Johannesburg
# Searching : Dunkeld, Johannesburg
# Searching : Dunkeld West, Johannesburg
# Searching : Eagles Nest, Johannesburg
# Searching : Eastcliff, Johannesburg
# Searching : Ebony Park, Johannesburg
# Searching : Edenburg, Johannesburg
# Searching : Elandspark, Johannesburg
# Searching : Elcedes, Johannesburg
# Searching : Eldorado Park, Johannesburg
# Searching : Electron, Johannesburg
# Searching : Elladoone, Johannesburg
# Searching : Elton Hill, Johannesburg
# Searching : Emmarentia, Johannesburg
# Searching : Ennerdale, Johannesburg
# Searching : Epsom Downs, Johannesburg
# Searching : Erand, Johannesburg
# Searching : Evans Park, Johannesburg
# Searching : Fairland, Johannesburg
# Searching : Fairview, Johannesburg
# Searching : Fairway, Johannesburg
# Searching : Fairwood, Johannesburg
# Searching : Farmall, Johannesburg
# Searching : Fellside, Johannesburg
# Searching : Ferndale, Johannesburg
# Searching : Ferreirasdorp, Johannesburg
# Searching : Florida, Johannesburg
# Searching : Florida Glen, Johannesburg
# Searching : Florida Hills, Johannesburg
# Searching : Fontainebleau, Johannesburg
# Searching : Forbesdale, Johannesburg
# Searching : Fordsburg, Johannesburg
# Searching : Forest Hill, Johannesburg
# Searching : Forest Town, Johannesburg
# Searching : Fourways, Johannesburg
# Searching : Framton, Johannesburg
# Searching : Gallo Manor, Johannesburg
# Searching : Gillview, Johannesburg
# Searching : Glen Athol, Johannesburg
# Searching : Glen Austin, Johannesburg
# Searching : Glenadrienne, Johannesburg
# Searching : Glenanda, Johannesburg
# Searching : Glenesk, Johannesburg
# Searching : Glenhazel, Johannesburg
# Searching : Gleniffer, Johannesburg
# Searching : Glenvista, Johannesburg
# Searching : Greenside, Johannesburg
# Searching : Greenstone Hill, Johannesburg
# Searching : Gresswold, Johannesburg
# Searching : Greymont, Johannesburg
# Searching : Haddon, Johannesburg
# Searching : Halfway Gardens, Johannesburg
# Searching : Halfway House Estate, Johannesburg
# Searching : Hawkins Estate, Johannesburg
# Searching : Headway Hill, Johannesburg
# Searching : Heriotdale, Johannesburg
# Searching : Highlands, Johannesburg
# Searching : Highlands North, Johannesburg
# Searching : Hillbrow, Johannesburg
# Searching : Homestead Park, Johannesburg
# Searching : Houghton Estate (part), Johannesburg
# Searching : Houtkoppen, Johannesburg
# Searching : Hurl Park, Johannesburg
# Searching : Hurlingham, Johannesburg
# Searching : Hurlingham Gardens, Johannesburg
# Searching : Hyde Park, Johannesburg
# Searching : Illovo, Johannesburg
# Searching : Inadan, Johannesburg
# Searching : Inanda, Johannesburg
# Searching : Ivory Park, Johannesburg
# Searching : Jan Hofmeyer, Johannesburg
# Searching : Jeppestown, Johannesburg
# Searching : Jeppestown South, Johannesburg
# Searching : Johannesburg, Johannesburg
# Searching : Johannesburg North, Johannesburg
# Searching : Johannesburg South, Johannesburg
# Searching : Joubert Park, Johannesburg
# Searching : Judith's Paarl, Johannesburg
# Searching : Jukskei Park, Johannesburg
# Searching : Kenilworth, Johannesburg
# Searching : Kensington, Johannesburg
# Searching : Kensington B, Johannesburg
# Searching : Kentview, Johannesburg
# Searching : Kew, Johannesburg
# Searching : Khyber Rock, Johannesburg
# Searching : Kibler Park, Johannesburg
# Searching : Killarney, Johannesburg
# Searching : Klevehill Park, Johannesburg
# Searching : Klipriviersberg, Johannesburg
# Searching : Klipriviersberg Estate, Johannesburg
# Searching : Kliptown, Johannesburg
# Searching : Kya Sand, Johannesburg
# Searching : Kya Sands, Johannesburg
# Searching : Kyalami Agricultural Holdings, Johannesburg
# Searching : Kyalami Business Park, Johannesburg
# Searching : Kyalami Estates, Johannesburg
# Searching : La Rochelle, Johannesburg
# Searching : Lake View Estate, Johannesburg
# Searching : Langlaagte North, Johannesburg
# Searching : Lawley, Johannesburg
# Searching : Lenasia, Johannesburg
# Searching : Liefde en Vrede, Johannesburg
# Searching : Lindberg Park, Johannesburg
# Searching : Linden, Johannesburg
# Searching : Linmeyer, Johannesburg
# Searching : Littlefillan, Johannesburg
# Searching : Lone Hill, Johannesburg
# Searching : Lorentzville, Johannesburg
# Searching : Lyme Park, Johannesburg
# Searching : Magalies View, Johannesburg
# Searching : Magaliessig, Johannesburg
# Searching : Malanshof, Johannesburg
# Searching : Malvern, Johannesburg
# Searching : Marlboro, Johannesburg
# Searching : Marlboro Gardens, Johannesburg
# Searching : Maroeladal, Johannesburg
# Searching : Marshalls, Johannesburg
# Searching : Marshalltown, Johannesburg
# Searching : Maryvale, Johannesburg
# Searching : Mayfair, Johannesburg
# Searching : Mayfield Park, Johannesburg
# Searching : Meadowlands, Johannesburg
# Searching : Melrose, Johannesburg
# Searching : Melrose Estate, Johannesburg
# Searching : Melrose North, Johannesburg
# Searching : Melville, Johannesburg
# Searching : Meredale, Johannesburg
# Searching : Midrand, Johannesburg
# Searching : Midridge Park, Johannesburg
# Searching : Mill Hill, Johannesburg
# Searching : Millgate Farm, Johannesburg
# Searching : Moffat View, Johannesburg
# Searching : Mondeor, Johannesburg
# Searching : Moodie Hill, Johannesburg
# Searching : Morningside, Johannesburg
# Searching : Morningside Manor, Johannesburg
# Searching : Mountain View, Johannesburg
# Searching : Mulbarton, Johannesburg
# Searching : Nasrec, Johannesburg
# Searching : New Brighton, Johannesburg
# Searching : New Centre, Johannesburg
# Searching : New Doornfontein, Johannesburg
# Searching : Newlands, Johannesburg
# Searching : Newtown, Johannesburg
# Searching : Nietgedacht, Johannesburg
# Searching : Noordgesig, Johannesburg
# Searching : Noordwyk, Johannesburg
# Searching : Norscot, Johannesburg
# Searching : North Champagne Estates, Johannesburg
# Searching : North Doornfontein, Johannesburg
# Searching : Northcliff, Johannesburg
# Searching : Northern Acres, Johannesburg
# Searching : Northgate, Johannesburg
# Searching : Northriding, Johannesburg
# Searching : Norwood, Johannesburg
# Searching : Oakdene, Johannesburg
# Searching : Oaklands, Johannesburg
# Searching : Observatory, Johannesburg
# Searching : Oerder Park, Johannesburg
# Searching : Olivedale, Johannesburg
# Searching : Ophirton, Johannesburg
# Searching : Orange Farm, Johannesburg
# Searching : Orange Grove, Johannesburg
# Searching : Orlando, Johannesburg
# Searching : Ormonde, Johannesburg
# Searching : Osummit, Johannesburg
# Searching : Pageview, Johannesburg
# Searching : Park Central, Johannesburg
# Searching : Parkhurst, Johannesburg
# Searching : Parkmore, Johannesburg
# Searching : Parktown, Johannesburg
# Searching : Parktown North, Johannesburg
# Searching : Parkview, Johannesburg
# Searching : Patlynn, Johannesburg
# Searching : Paulshof, Johannesburg
# Searching : Percelia Estate, Johannesburg
# Searching : Petervale, Johannesburg
# Searching : Phiri, Johannesburg
# Searching : Plooysville, Johannesburg
# Searching : Praegville, Johannesburg
# Searching : President Ridge, Johannesburg
# Searching : Prolecon, Johannesburg
# Searching : Protea Glen, Johannesburg
# Searching : Rabie Ridge, Johannesburg
# Searching : Raedene Estate, Johannesburg
# Searching : Randburg, Johannesburg
# Searching : Randjesfontein AH, Johannesburg
# Searching : Randjespark, Johannesburg
# Searching : Randpark, Johannesburg
# Searching : Randpark Ridge, Johannesburg
# Searching : Randview, Johannesburg
# Searching : Raumarais Park, Johannesburg
# Searching : Regency, Johannesburg
# Searching : Regents Park, Johannesburg
# Searching : Regents Park Estate, Johannesburg
# Searching : Reuven, Johannesburg
# Searching : Rewlatch, Johannesburg
# Searching : Reynolds View, Johannesburg
# Searching : Ridgeway, Johannesburg
# Searching : Riepen Park, Johannesburg
# Searching : Risana, Johannesburg
# Searching : Rispark, Johannesburg
# Searching : River Bend, Johannesburg
# Searching : River Club, Johannesburg
# Searching : Riverbend AH, Johannesburg
# Searching : Riviera, Johannesburg
# Searching : Rivonia, Johannesburg
# Searching : Robertsham, Johannesburg
# Searching : Roodepoort, Johannesburg
# Searching : Roseacre, Johannesburg
# Searching : Rosebank, Johannesburg
# Searching : Rosettenville, Johannesburg
# Searching : Ruiterhof, Johannesburg
# Searching : Salfred, Johannesburg
# Searching : Salisbury Claims, Johannesburg
# Searching : Sandhurst, Johannesburg
# Searching : Sandown, Johannesburg
# Searching : Sandton, Johannesburg
# Searching : Savoy Estate, Johannesburg
# Searching : Saxonwold, Johannesburg
# Searching : Selby, Johannesburg
# Searching : Simba, Johannesburg
# Searching : Solridge, Johannesburg
# Searching : Sophiatown, Johannesburg
# Searching : South Hills, Johannesburg
# Searching : Southdale, Johannesburg
# Searching : Southfork, Johannesburg
# Searching : Southgate, Johannesburg
# Searching : Soweto, Johannesburg
# Searching : Spes Bona, Johannesburg
# Searching : Springfield, Johannesburg
# Searching : Stafford, Johannesburg
# Searching : Steeledale, Johannesburg
# Searching : Strathavon, Johannesburg
# Searching : Strijdompark, Johannesburg
# Searching : Suideroord, Johannesburg
# Searching : Sunningdale, Johannesburg
# Searching : Sunningdale Ridge, Johannesburg
# Searching : Sunninghill, Johannesburg
# Searching : Sunrella, Johannesburg
# Searching : Sunset Acres, Johannesburg
# Searching : Sydenham, Johannesburg
# Searching : The Gables, Johannesburg
# Searching : The Gardens, Johannesburg
# Searching : The Hill, Johannesburg
# Searching : Theta, Johannesburg
# Searching : Towerby, Johannesburg
# Searching : Townsview, Johannesburg
# Searching : Trevallyn, Johannesburg
# Searching : Trojan, Johannesburg
# Searching : Troyeville, Johannesburg
# Searching : Tulisa Park, Johannesburg
# Searching : Turf Club, Johannesburg
# Searching : Turffontein, Johannesburg
# Searching : Vandia Grove, Johannesburg
# Searching : Victoria, Johannesburg
# Searching : Village Main, Johannesburg
# Searching : Vorna Valley, Johannesburg
# Searching : Vrededorp, Johannesburg
# Searching : Waterval City, Johannesburg
# Searching : Waterval Estate, Johannesburg
# Searching : Weltevredenpark, Johannesburg
# Searching : Westcliff, Johannesburg
# Searching : Westdene, Johannesburg
# Searching : Wierda Valley, Johannesburg
# Searching : Willaway, Johannesburg
# Searching : Willowild, Johannesburg
# Searching : Witkoppen, Johannesburg
# Searching : Woodlands, Johannesburg
# Searching : Woodmead, Johannesburg
# Searching : Wynberg, Johannesburg
# Searching : Yeoville, Johannesburg
# Searching : Zandspruit, Johannesburg
# Searching : Zola, Johannesburg

# %%
# Convert the list of dictionaries to a dataframe
loc_df = pd.DataFrame(locdata)

# Display some high level information of the dataframe
print('dataframe shape')
loc_df.shape
# Out:
# dataframe shape
# (493, 4)

# %%
print('dataframe head')
loc_df.head()
# Out:
# dataframe head
#             searchstring                                            address  \
# 0     Athlone, Cape Town  Athlone, Cape Town Ward 49, Cape Town, City of...
# 1    Atlantis, Cape Town  Atlantis, City of Cape Town, Western Cape, Sou...
# 2     Bakoven, Cape Town  Bakoven, Camps Bay, Cape Town, City of Cape To...
# 3  Bantry Bay, Cape Town  Bantry Bay, Cape Town, City of Cape Town, West...
# 4      Belhar, Cape Town  Belhar, Cape Town Ward 22, City of Cape Town, ...
#
#    longitude   latitude
# 0  18.505000 -33.966667
# 1  18.500278 -33.567222
# 2  18.382778 -33.960000
# 3  18.378970 -33.928151
# 4  18.625833 -33.944722

# %% [markdown]
# ### Cleaning the location dataframe
#
# There are unfortunately problems with the dataset.
# - locations that could not be found
# - locations that were found but aren't the ones intended (other countries)
# - searchstring and address columns are actually not needed post cleanup

# %%
# Cleaning location dataframe

# Filter out locations that could not be found
loc_df = loc_df.dropna()

# Filter out results that are not in South Africa
loc_df = loc_df[ loc_df.address.str.contains("South Africa") ]

# Adding two new columns to the existing dataframe. for city and neighbourhood based on the searchstring
loc_df[['neighborhood','city']] = loc_df.searchstring.str.split(", ",expand=True)

# Remove searchstring and address columns as they are no longer needed.
# This will be the baseline location data that we will use for analysis.
loc_df = loc_df.drop(columns=['address', 'searchstring'])

# reset the index
loc_df.reset_index(inplace=True,drop=True)

# %%
# Display some high level information of the dataframe
print('dataframe shape')
loc_df.shape
# Out:
# dataframe shape
# (408, 4)

# %%
print('dataframe head')
loc_df.head()
# Out:
# dataframe head
#    longitude   latitude neighborhood       city
# 0  18.505000 -33.966667      Athlone  Cape Town
# 1  18.500278 -33.567222     Atlantis  Cape Town
# 2  18.382778 -33.960000      Bakoven  Cape Town
# 3  18.378970 -33.928151   Bantry Bay  Cape Town
# 4  18.625833 -33.944722       Belhar  Cape Town

# %% [markdown]
# ### Exploring the Venues in all the neighborhoods
#
# Now that we have a dataframe with the neighborhoods and coordinates, it is time to add all the nearby venues.
# We will be using the FourSquare API to gather this information.

# %%
# Define function for exploring a location for all nearby venues
def getNearbyVenues(neighborhoods, cities, latitudes, longitudes):

    venues_list=[]
    for neighborhood, city, lat, lng in zip(neighborhoods, cities, latitudes, longitudes):
        print("Exploring : {} - {}".format(city, neighborhood).rstrip()) # Print current search to track progress
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            LIMIT)

        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            neighborhood,
            city,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'City', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Gather all venues into a dataframe
all_venues = getNearbyVenues(neighborhoods = loc_df['neighborhood'],
                             cities = loc_df['city'], 
                             latitudes = loc_df['latitude'],
                             longitudes = loc_df['longitude']
                             )
# Out:
# Exploring : Cape Town - Athlone
# Exploring : Cape Town - Atlantis
# Exploring : Cape Town - Bakoven
# Exploring : Cape Town - Bantry Bay
# Exploring : Cape Town - Belhar
# Exploring : Cape Town - Bellville
# Exploring : Cape Town - Bergvliet
# Exploring : Cape Town - Bishop Lavis
# Exploring : Cape Town - Bishopscourt
# Exploring : Cape Town - Bloubergstrand
# Exploring : Cape Town - Bo-Kaap
# Exploring : Cape Town - Bonteheuwel
# Exploring : Cape Town - Bothasig
# Exploring : Cape Town - Brackenfell
# Exploring : Cape Town - Brooklyn
# Exploring : Cape Town - Camps Bay
# Exploring : Cape Town - Capri Village
# Exploring : Cape Town - Claremont
# Exploring : Cape Town - Clifton
# Exploring : Cape Town - Clovelly
# Exploring : Cape Town - Constantia
# Exploring : Cape Town - Crawford
# Exploring : Cape Town - Crossroads
# Exploring : Cape Town - Darling
# Exploring : Cape Town - De Waterkant
# Exploring : Cape Town - Delft
# Exploring : Cape Town - Devil's Peak Estate
# Exploring : Cape Town - Diep River
# Exploring : Cape Town - Durbanville
# Exploring : Cape Town - Edgemead
# Exploring : Cape Town - Eersteriver
# Exploring : Cape Town - Elsie's River
# Exploring : Cape Town - Epping
# Exploring : Cape Town - Firgrove
# Exploring : Cape Town - Fish Hoek
# Exploring : Cape Town - Foreshore
# Exploring : Cape Town - Fresnaye
# Exploring : Cape Town - Gardens
# Exploring : Cape Town - Glencairn
# Exploring : Cape Town - Goodwood
# Exploring : Cape Town - Gordon's Bay
# Exploring : Cape Town - Grassy Park
# Exploring : Cape Town - Green Point
# Exploring : Cape Town - Gugulethu
# Exploring : Cape Town - Hanover Park
# Exploring : Cape Town - Harfield Village
# Exploring : Cape Town - Heathfield
# Exploring : Cape Town - Hout Bay
# Exploring : Cape Town - Imizamo Yethu
# Exploring : Cape Town - Kalk Bay
# Exploring : Cape Town - Kalksteenfontein
# Exploring : Cape Town - Kenilworth
# Exploring : Cape Town - Kensington
# Exploring : Cape Town - Kenwyn
# Exploring : Cape Town - Khayelitsha
# Exploring : Cape Town - Kirstenhof
# Exploring : Cape Town - Kommetjie
# Exploring : Cape Town - Kraaifontein
# Exploring : Cape Town - Kreupelbosch
# Exploring : Cape Town - Kuils River
# Exploring : Cape Town - Lakeside
# Exploring : Cape Town - Langa
# Exploring : Cape Town - Lansdowne
# Exploring : Cape Town - Lavender Hill
# Exploring : Cape Town - Llandudno
# Exploring : Cape Town - Loevenstein
# Exploring : Cape Town - Lotus River
# Exploring : Cape Town - Macassar
# Exploring : Cape Town - Maitland
# Exploring : Cape Town - Mamre
# Exploring : Cape Town - Manenberg
# Exploring : Cape Town - Marina da Gama
# Exploring : Cape Town - Masiphumelele
# Exploring : Cape Town - Meadowridge
# Exploring : Cape Town - Melkbosstrand
# Exploring : Cape Town - Milnerton
# Exploring : Cape Town - Mitchells Plain
# Exploring : Cape Town - Montague Gardens
# Exploring : Cape Town - Monte Vista
# Exploring : Cape Town - Mouille Point
# Exploring : Cape Town - Mowbray
# Exploring : Cape Town - Muizenberg
# Exploring : Cape Town - Ndabeni
# Exploring : Cape Town - Newlands
# Exploring : Cape Town - Noordhoek
# Exploring : Cape Town - Nyanga
# Exploring : Cape Town - Observatory
# Exploring : Cape Town - Ocean View
# Exploring : Cape Town - Oranjezicht
# Exploring : Cape Town - Ottery
# Exploring : Cape Town - Panorama
# Exploring : Cape Town - Parklands
# Exploring : Cape Town - Parow
# Exploring : Cape Town - Pelican Park
# Exploring : Cape Town - Philippi
# Exploring : Cape Town - Pinelands
# Exploring : Cape Town - Plattekloof
# Exploring : Cape Town - Plumstead
# Exploring : Cape Town - Retreat
# Exploring : Cape Town - Rondebosch
# Exploring : Cape Town - Rondebosch East
# Exploring : Cape Town - Rosebank
# Exploring : Cape Town - Rugby
# Exploring : Cape Town - Salt River
# Exploring : Cape Town - Samora Machel
# Exploring : Cape Town - Scarborough
# Exploring : Cape Town - Schotsche Kloof
# Exploring : Cape Town - Sea Point
# Exploring : Cape Town - Simon's Town
# Exploring : Cape Town - Sir Lowry's Pass Village
# Exploring : Cape Town - Somerset West
# Exploring : Cape Town - SouthField
# Exploring : Cape Town - St James
# Exploring : Cape Town - Steenberg
# Exploring : Cape Town - Strand
# Exploring : Cape Town - Strandfontein
# Exploring : Cape Town - Sun Valley
# Exploring : Cape Town - Sunnydale
# Exploring : Cape Town - Table View
# Exploring : Cape Town - Tamboerskloof
# Exploring : Cape Town - Thornton
# Exploring : Cape Town - Three Anchor Bay
# Exploring : Cape Town - Tokai
# Exploring : Cape Town - Valhalla Park
# Exploring : Cape Town - Vredehoek
# Exploring : Cape Town - Vrygrond
# Exploring : Cape Town - Walmer Estate
# Exploring : Cape Town - West Beach
# Exploring : Cape Town - Wetton
# Exploring : Cape Town - Woodstock
# Exploring : Cape Town - Wynberg
# Exploring : Cape Town - Zonnebloem
# Exploring : Johannesburg - Abbotsford
# Exploring : Johannesburg - Aeroton
# Exploring : Johannesburg - Airdlin
# Exploring : Johannesburg - Alan Manor
# Exploring : Johannesburg - Albertskroon
# Exploring : Johannesburg - Albertville
# Exploring : Johannesburg - Aldara Park
# Exploring : Johannesburg - Alexandra
# Exploring : Johannesburg - Amalgam
# Exploring : Johannesburg - Atholhurst
# Exploring : Johannesburg - Atholl
# Exploring : Johannesburg - Atholl Gardens
# Exploring : Johannesburg - Auckland Park
# Exploring : Johannesburg - Barbeque Downs
# Exploring : Johannesburg - Bellevue
# Exploring : Johannesburg - Bellevue East
# Exploring : Johannesburg - Benmore Gardens
# Exploring : Johannesburg - Benrose
# Exploring : Johannesburg - Berario
# Exploring : Johannesburg - Berea
# Exploring : Johannesburg - Bertrams
# Exploring : Johannesburg - Beverley Gardens
# Exploring : Johannesburg - Birdhaven
# Exploring : Johannesburg - Birnam
# Exploring : Johannesburg - Blackheath
# Exploring : Johannesburg - Blairgowrie
# Exploring : Johannesburg - Bloubosrand
# Exploring : Johannesburg - Blue Hills
# Exploring : Johannesburg - Bordeaux
# Exploring : Johannesburg - Bosmont
# Exploring : Johannesburg - Braamfontein
# Exploring : Johannesburg - Bramley
# Exploring : Johannesburg - Bramley North
# Exploring : Johannesburg - Bramley Park
# Exploring : Johannesburg - Brixton
# Exploring : Johannesburg - Broadacres
# Exploring : Johannesburg - Bromhof
# Exploring : Johannesburg - Bruma
# Exploring : Johannesburg - Bryanston
# Exploring : Johannesburg - Bryanston East
# Exploring : Johannesburg - Bryanston West
# Exploring : Johannesburg - Buccleuch
# Exploring : Johannesburg - Bush Hill
# Exploring : Johannesburg - Carlswald
# Exploring : Johannesburg - Chartwell
# Exploring : Johannesburg - Cheltondale
# Exploring : Johannesburg - Chrisville
# Exploring : Johannesburg - City Deep
# Exploring : Johannesburg - Constantia Kloof
# Exploring : Johannesburg - Country View
# Exploring : Johannesburg - Craighall
# Exploring : Johannesburg - Craighall Park
# Exploring : Johannesburg - Cresta
# Exploring : Johannesburg - Crosby
# Exploring : Johannesburg - Crown
# Exploring : Johannesburg - Crown Gardens
# Exploring : Johannesburg - Crown North
# Exploring : Johannesburg - Crowthorne
# Exploring : Johannesburg - Cyrildene
# Exploring : Johannesburg - Dainfern
# Exploring : Johannesburg - Darrenwood
# Exploring : Johannesburg - Diepkloof
# Exploring : Johannesburg - Diepsloot
# Exploring : Johannesburg - Dobsonville
# Exploring : Johannesburg - Doornfontein
# Exploring : Johannesburg - Doornkop
# Exploring : Johannesburg - Douglasdale
# Exploring : Johannesburg - Dunkeld
# Exploring : Johannesburg - Dunkeld West
# Exploring : Johannesburg - Eagles Nest
# Exploring : Johannesburg - Ebony Park
# Exploring : Johannesburg - Elandspark
# Exploring : Johannesburg - Eldorado Park
# Exploring : Johannesburg - Electron
# Exploring : Johannesburg - Elton Hill
# Exploring : Johannesburg - Emmarentia
# Exploring : Johannesburg - Ennerdale
# Exploring : Johannesburg - Erand
# Exploring : Johannesburg - Evans Park
# Exploring : Johannesburg - Fairland
# Exploring : Johannesburg - Fairview
# Exploring : Johannesburg - Fairway
# Exploring : Johannesburg - Ferndale
# Exploring : Johannesburg - Florida
# Exploring : Johannesburg - Florida Glen
# Exploring : Johannesburg - Florida Hills
# Exploring : Johannesburg - Fontainebleau
# Exploring : Johannesburg - Fordsburg
# Exploring : Johannesburg - Forest Hill
# Exploring : Johannesburg - Forest Town
# Exploring : Johannesburg - Fourways
# Exploring : Johannesburg - Gallo Manor
# Exploring : Johannesburg - Gillview
# Exploring : Johannesburg - Glen Austin
# Exploring : Johannesburg - Glenanda
# Exploring : Johannesburg - Glenhazel
# Exploring : Johannesburg - Glenvista
# Exploring : Johannesburg - Greenside
# Exploring : Johannesburg - Greenstone Hill
# Exploring : Johannesburg - Gresswold
# Exploring : Johannesburg - Greymont
# Exploring : Johannesburg - Haddon
# Exploring : Johannesburg - Headway Hill
# Exploring : Johannesburg - Heriotdale
# Exploring : Johannesburg - Highlands
# Exploring : Johannesburg - Highlands North
# Exploring : Johannesburg - Hillbrow
# Exploring : Johannesburg - Homestead Park
# Exploring : Johannesburg - Hurlingham
# Exploring : Johannesburg - Hurlingham Gardens
# Exploring : Johannesburg - Hyde Park
# Exploring : Johannesburg - Illovo
# Exploring : Johannesburg - Inanda
# Exploring : Johannesburg - Ivory Park
# Exploring : Johannesburg - Jeppestown
# Exploring : Johannesburg - Jeppestown South
# Exploring : Johannesburg - Johannesburg North
# Exploring : Johannesburg - Joubert Park
# Exploring : Johannesburg - Judith's Paarl
# Exploring : Johannesburg - Jukskei Park
# Exploring : Johannesburg - Kenilworth
# Exploring : Johannesburg - Kensington
# Exploring : Johannesburg - Kensington B
# Exploring : Johannesburg - Kew
# Exploring : Johannesburg - Kibler Park
# Exploring : Johannesburg - Killarney
# Exploring : Johannesburg - Klipriviersberg
# Exploring : Johannesburg - Kliptown
# Exploring : Johannesburg - Kya Sand
# Exploring : Johannesburg - Kya Sands
# Exploring : Johannesburg - Kyalami Business Park
# Exploring : Johannesburg - La Rochelle
# Exploring : Johannesburg - Langlaagte North
# Exploring : Johannesburg - Lawley
# Exploring : Johannesburg - Lenasia
# Exploring : Johannesburg - Linden
# Exploring : Johannesburg - Linmeyer
# Exploring : Johannesburg - Lyme Park
# Exploring : Johannesburg - Magalies View
# Exploring : Johannesburg - Magaliessig
# Exploring : Johannesburg - Malanshof
# Exploring : Johannesburg - Malvern
# Exploring : Johannesburg - Marlboro
# Exploring : Johannesburg - Marlboro Gardens
# Exploring : Johannesburg - Maroeladal
# Exploring : Johannesburg - Marshalltown
# Exploring : Johannesburg - Maryvale
# Exploring : Johannesburg - Mayfair
# Exploring : Johannesburg - Mayfield Park
# Exploring : Johannesburg - Meadowlands
# Exploring : Johannesburg - Melrose
# Exploring : Johannesburg - Melrose Estate
# Exploring : Johannesburg - Melrose North
# Exploring : Johannesburg - Melville
# Exploring : Johannesburg - Midrand
# Exploring : Johannesburg - Mill Hill
# Exploring : Johannesburg - Moffat View
# Exploring : Johannesburg - Mondeor
# Exploring : Johannesburg - Moodie Hill
# Exploring : Johannesburg - Morningside
# Exploring : Johannesburg - Morningside Manor
# Exploring : Johannesburg - Mountain View
# Exploring : Johannesburg - Mulbarton
# Exploring : Johannesburg - Nasrec
# Exploring : Johannesburg - New Brighton
# Exploring : Johannesburg - New Centre
# Exploring : Johannesburg - New Doornfontein
# Exploring : Johannesburg - Newlands
# Exploring : Johannesburg - Newtown
# Exploring : Johannesburg - Noordgesig
# Exploring : Johannesburg - Noordwyk
# Exploring : Johannesburg - Norscot
# Exploring : Johannesburg - North Doornfontein
# Exploring : Johannesburg - Northcliff
# Exploring : Johannesburg - Northgate
# Exploring : Johannesburg - Northriding
# Exploring : Johannesburg - Norwood
# Exploring : Johannesburg - Oakdene
# Exploring : Johannesburg - Oaklands
# Exploring : Johannesburg - Observatory
# Exploring : Johannesburg - Oerder Park
# Exploring : Johannesburg - Olivedale
# Exploring : Johannesburg - Ophirton
# Exploring : Johannesburg - Orange Farm
# Exploring : Johannesburg - Orange Grove
# Exploring : Johannesburg - Orlando
# Exploring : Johannesburg - Ormonde
# Exploring : Johannesburg - Park Central
# Exploring : Johannesburg - Parkhurst
# Exploring : Johannesburg - Parkmore
# Exploring : Johannesburg - Parktown
# Exploring : Johannesburg - Parktown North
# Exploring : Johannesburg - Parkview
# Exploring : Johannesburg - Paulshof
# Exploring : Johannesburg - Petervale
# Exploring : Johannesburg - Phiri
# Exploring : Johannesburg - President Ridge
# Exploring : Johannesburg - Prolecon
# Exploring : Johannesburg - Protea Glen
# Exploring : Johannesburg - Rabie Ridge
# Exploring : Johannesburg - Randburg
# Exploring : Johannesburg - Randjespark
# Exploring : Johannesburg - Randpark
# Exploring : Johannesburg - Randpark Ridge
# Exploring : Johannesburg - Randview
# Exploring : Johannesburg - Raumarais Park
# Exploring : Johannesburg - Regency
# Exploring : Johannesburg - Regents Park
# Exploring : Johannesburg - Rewlatch
# Exploring : Johannesburg - Reynolds View
# Exploring : Johannesburg - Ridgeway
# Exploring : Johannesburg - Riepen Park
# Exploring : Johannesburg - Risana
# Exploring : Johannesburg - Rispark
# Exploring : Johannesburg - River Bend
# Exploring : Johannesburg - River Club
# Exploring : Johannesburg - Riverbend AH
# Exploring : Johannesburg - Riviera
# Exploring : Johannesburg - Rivonia
# Exploring : Johannesburg - Robertsham
# Exploring : Johannesburg - Roodepoort
# Exploring : Johannesburg - Roseacre
# Exploring : Johannesburg - Rosebank
# Exploring : Johannesburg - Rosettenville
# Exploring : Johannesburg - Ruiterhof
# Exploring : Johannesburg - Sandhurst
# Exploring : Johannesburg - Sandown
# Exploring : Johannesburg - Sandton
# Exploring : Johannesburg - Savoy Estate
# Exploring : Johannesburg - Saxonwold
# Exploring : Johannesburg - Selby
# Exploring : Johannesburg - Simba
# Exploring : Johannesburg - Sophiatown
# Exploring : Johannesburg - South Hills
# Exploring : Johannesburg - Southdale
# Exploring : Johannesburg - Southfork
# Exploring : Johannesburg - Southgate
# Exploring : Johannesburg - Soweto
# Exploring : Johannesburg - Springfield
# Exploring : Johannesburg - Stafford
# Exploring : Johannesburg - Steeledale
# Exploring : Johannesburg - Strathavon
# Exploring : Johannesburg - Suideroord
# Exploring : Johannesburg - Sunningdale
# Exploring : Johannesburg - Sunningdale Ridge
# Exploring : Johannesburg - Sunninghill
# Exploring : Johannesburg - Sydenham
# Exploring : Johannesburg - The Gables
# Exploring : Johannesburg - The Gardens
# Exploring : Johannesburg - The Hill
# Exploring : Johannesburg - Theta
# Exploring : Johannesburg - Towerby
# Exploring : Johannesburg - Townsview
# Exploring : Johannesburg - Trojan
# Exploring : Johannesburg - Troyeville
# Exploring : Johannesburg - Tulisa Park
# Exploring : Johannesburg - Turf Club
# Exploring : Johannesburg - Turffontein
# Exploring : Johannesburg - Vandia Grove
# Exploring : Johannesburg - Victoria
# Exploring : Johannesburg - Village Main
# Exploring : Johannesburg - Vorna Valley
# Exploring : Johannesburg - Vrededorp
# Exploring : Johannesburg - Waterval City
# Exploring : Johannesburg - Waterval Estate
# Exploring : Johannesburg - Weltevredenpark
# Exploring : Johannesburg - Westcliff
# Exploring : Johannesburg - Westdene
# Exploring : Johannesburg - Wierda Valley
# Exploring : Johannesburg - Witkoppen
# Exploring : Johannesburg - Woodlands
# Exploring : Johannesburg - Woodmead
# Exploring : Johannesburg - Wynberg
# Exploring : Johannesburg - Yeoville
# Exploring : Johannesburg - Zandspruit
# Exploring : Johannesburg - Zola

# %%
# Need to create a key based on city and neighborhood as an index
all_venues['ID'] = all_venues['City'] + '_' + all_venues['Neighborhood']

# %%
print('dataframe head')
all_venues.head()
# Out:
# dataframe head
#   Neighborhood       City  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Athlone  Cape Town             -33.966667                  18.505
# 1      Athlone  Cape Town             -33.966667                  18.505
# 2      Athlone  Cape Town             -33.966667                  18.505
# 3      Athlone  Cape Town             -33.966667                  18.505
# 4      Athlone  Cape Town             -33.966667                  18.505
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0              Wembley Roadhouse      -33.965429        18.514660
# 1             Common Ground Cafe      -33.958918        18.485833
# 2  Western Province Cricket Club      -33.973314        18.482350
# 3              Rondebosch Common      -33.959344        18.484840
# 4                      Starlings      -33.980100        18.481972
#
#        Venue Category                 ID
# 0        Burger Joint  Cape Town_Athlone
# 1         Coffee Shop  Cape Town_Athlone
# 2  Athletics & Sports  Cape Town_Athlone
# 3                Park  Cape Town_Athlone
# 4                Café  Cape Town_Athlone
